# %% [markdown]
# <div style="text-align: center; font-size: 24px;">
# Нахождение общего решение линейной однородной системы дифференциальных уравнений 1-го порядка с постоянными коэффициентами матричным методом при различных случаях корней характеристического уравнения.
# </div>

# %% [markdown]
# Рассмотрим систему $:$
#
# $$
# \frac{d\mathbf{x}}{dt} = A\mathbf{x},
# $$
#
# где $\mathbf{x} = (x_1, x_2, \dots, x_n)^T$ — вектор-функция, $A$ — постоянная матрица $n \times n$.

# %% [markdown]
# **Общий алгоритм решения $:$**
#
# 1. **Находим собственные значения матрицы $A$ $:$**
#    Решаем характеристическое уравнение $:$
# $$
#    \det(A - \lambda I) = 0.
# $$
#    Корни $\lambda_1, \lambda_2, \dots, \lambda_n$ могут быть действительными или комплексными, кратными или простыми.
#
# 2. **Находим собственные и присоединённые векторы $:$**
#    Для каждого $\lambda_i$ находим соответствующие собственные векторы $\mathbf{v}_i$ (или жордановы цепочки, если корень кратный).
#
# 3. **Формируем фундаментальную систему решений (ФСР) $:$**
#    - Если $\lambda$ — **простой корень**, то решение имеет вид $:$
# $$
#      \mathbf{x}_i(t) = \mathbf{v}_i e^{\lambda_i t}.
# $$
#    - Если $\lambda$ — **кратный корень кратности $k$**, то ищем решения в виде $:$
# $$
#      \mathbf{x}_i(t) = \left( \mathbf{v}_0 + t \mathbf{v}_1 + \dots + \frac{t^{k-1}}{(k-1)!} \mathbf{v}_{k-1} \right) e^{\lambda t},
# $$
# где $\mathbf{v}_0, \mathbf{v}_1, \dots$ — векторы жордановой цепочки.
#
# 4. **Общее решение $:$**
#    Линейная комбинация всех найденных решений $:$
# $$
#    \mathbf{x}(t) = \sum_{i=1}^n C_i \mathbf{x}_i(t),
# $$
#    где $C_i$ — произвольные постоянные.

# %% [markdown]
# **Различные случаи корней характеристического уравнения $:$**
#
# **Случай 1. Все корни действительные и различные**
#
# - **Характеристическое уравнение** имеет $n$ различных действительных корней $\lambda_1, \lambda_2, \dots, \lambda_n$.
# - **Собственные векторы** $\mathbf{v}_1, \mathbf{v}_2, \dots, \mathbf{v}_n$ линейно независимы.
# - **Общее решение $:$**
# $$
#   \mathbf{x}(t) = C_1 \mathbf{v}_1 e^{\lambda_1 t} + C_2 \mathbf{v}_2 e^{\lambda_2 t} + \dots + C_n \mathbf{v}_n e^{\lambda_n t}.
# $$
#
# **Случай 2. Корни комплексные**
#
# - Если $\lambda = \alpha \pm i\beta$ — пара комплексно-сопряжённых корней, то им соответствуют комплексные собственные векторы $\mathbf{v} = \mathbf{a} \pm i\mathbf{b}$.
# - **Два действительных решения $:$**
# $$
#   \mathbf{x}_1(t) = e^{\alpha t} (\mathbf{a} \cos \beta t - \mathbf{b} \sin \beta t),
# $$
# $$
#   \mathbf{x}_2(t) = e^{\alpha t} (\mathbf{a} \sin \beta t + \mathbf{b} \cos \beta t).
# $$
# - **Общее решение** включает линейную комбинацию этих решений.
#
# **Случай 3. Кратные корни (недостаток собственных векторов)**
#
# - Если $\lambda$ — корень кратности $k$, но ему соответствует только $m < k$ линейно независимых собственных векторов, то дополняем их **присоединёнными векторами** из жордановой цепочки.
# - **Пример для $k=2$, $m=1$ $:$**
# $$
#   \mathbf{x}_1(t) = \mathbf{v}_1 e^{\lambda t}, \quad \mathbf{x}_2(t) = (\mathbf{v}_1 t + \mathbf{v}_2) e^{\lambda t},
# $$
# где $(A - \lambda I)\mathbf{v}_2 = \mathbf{v}_1$.
