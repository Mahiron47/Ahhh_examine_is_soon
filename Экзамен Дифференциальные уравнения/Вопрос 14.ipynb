# %% [markdown]
# <div style="text-align: center; font-size: 24px;">
# Дифференциальные уравнения n-го порядка. Простейшие случаи понижения порядка дифференциального уравнения. Нахождение интегрируемых комбинаций.
# </div>

# %% [markdown]
# Дифференциальное уравнение $n$-ого порядка
# $$
# F(y(x),\,y'(x),\,...,\,y^{(n)},\,x)=0\qquad a<x<b
# $$
# Дифференциальное уравнение $n$-ого порядка разрешённое относительнос старшей производной
# $$
# y^{(n)}(x)=f(y(x),\,y'(x),\,...,\,y^{(n\,-\,1)},\,x)
# $$

# %% [markdown]
# Общее решение дифф уравнений $n$-ых степеней
# $$
# y(x,\,C_1,\,C_2,\,\ldots,\,C_n)=0
# $$
# Способы понижения порядка дифф уравнений

# %% [markdown]
# 1. Уравнение вида $y^{(n)} = f(x)$
#
# Решение: последовательное интегрирование
#
# $y^{(n-1)} = \displaystyle\int f(x)dx + C_1$
#
# $y^{(n-2)} = \displaystyle\int y^{(n-1)}dx + C_2$
#
# $\ldots\ \ldots\ \ldots\ \ldots\ \ldots\ \ldots\ \ldots$
#
# $y = \displaystyle\int y'dx + C_n$

# %% [markdown]
# 2. Уравнение не содержит явно искомую функцию $y$ и её производные до порядка $(k-1)$ включительно:
#
# $F(x, y^{(k)}, y^{(k+1)}, \ldots, y^{(n)}) = 0$
#
# Решение: вводим замену $z = y^{(k)}$, получаем уравнение порядка $(n-k)$:
#
# $F(x, z, z', \ldots, z^{(n-k)}) = 0$

# %% [markdown]
# 3. Нахождение интегрированной комбинации
# Справедливо выражение
# $$
# \frac{d}{dx}Ф(x,\,y,\,y',\,...,\,y^{(n-1)})=F(x,\,y,\,y',\,...,\,y^{(n)})=0
# $$
# Тогда справедливо и
# $$
# Ф(x,\,y,\,y',\,...,\,y^{(n-1)})=C
# $$

# %% [markdown]
# 4. Интегрирующий множитель
# $$
# \mu(x,\,y)Ф(x,\,y,\,y',\,...,\,y^{(n)})=0
# $$
# Возможно подобрать интегрирующий множитель такой, после которого возможно преобразование
# $$
# \frac{d}{dx}Ф(x,\,y,\,y',\,...,\,y^{(n\,-\,1)})=0
# $$
# Проинтегрируем обе части
# $$
# Ф(x,\,y,\,y',\,...,\,y^{(n\,-\,1)})=C
# $$
