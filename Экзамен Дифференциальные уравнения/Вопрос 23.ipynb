# %% [markdown]
# <div style="text-align: center; font-size: 24px;">
# Системы дифференциальных уравнений 1-го порядка. Векторная форма записи. Сведение к одному дифференциальному уравнению более высокого порядка.
# </div>

# %% [markdown]
# Система дифференциальных уравнений 1-го порядка имеет вид:
# $$
# \begin{cases}
# \frac{dx_1}{dt} = f_1(t, x_1, x_2, \dots, x_n), \\
# \frac{dx_2}{dt} = f_2(t, x_1, x_2, \dots, x_n), \\
# \vdots \\
# \frac{dx_n}{dt} = f_n(t, x_1, x_2, \dots, x_n),
# \end{cases}
# $$
# где $x_1(t), x_2(t), \dots, x_n(t)$ — неизвестные функции, $t$ — независимая переменная (обычно время), $f_i$ — заданные функции.

# %% [markdown]
# Введём вектор-функцию:
# $$
# \mathbf{x}(t) = \begin{pmatrix} x_1(t) \\ x_2(t) \\ \vdots \\ x_n(t) \end{pmatrix}, \quad \mathbf{f}(t, \mathbf{x}) = \begin{pmatrix} f_1(t, \mathbf{x}) \\ f_2(t, \mathbf{x}) \\ \vdots \\ f_n(t, \mathbf{x}) \end{pmatrix}.
# $$
# Тогда систему можно записать в компактной **векторной форме**:
# $$
# \frac{d\mathbf{x}}{dt} = \mathbf{f}(t, \mathbf{x}).
# $$
# Это уравнение аналогично скалярному ДУ 1-го порядка, но в векторном пространстве.

# %% [markdown]
# **Сведение системы к одному уравнению более высокого порядка**
#
# Иногда систему ДУ 1-го порядка можно свести к одному дифференциальному уравнению более высокого порядка относительно одной из функций. Рассмотрим пример.
#
# **Пример:**
# Дана система:
# $$
# \begin{cases}
# \frac{dx}{dt} = y, \\
# \frac{dy}{dt} = -x.
# \end{cases}
# $$
# **Решение:**
# 1. Продифференцируем первое уравнение по $t$:
#    $$
#    \frac{d^2x}{dt^2} = \frac{dy}{dt}.
#    $$
# 2. Подставим второе уравнение $\frac{dy}{dt} = -x$:
#    $$
#    \frac{d^2x}{dt^2} = -x.
#    $$
# 3. Получили линейное ДУ 2-го порядка:
#    $$
#    x'' + x = 0.
#    $$
# 4. Решаем его:
#    $$
#    x(t) = C_1 \cos t + C_2 \sin t.
#    $$
# 5. Теперь находим $y(t)$ из первого уравнения:
#    $$
#    y = \frac{dx}{dt} = -C_1 \sin t + C_2 \cos t.
#    $$
#
# **Общий метод сведения:**
# 1. Выразить все функции, кроме одной, через производные выбранной функции.
# 2. Дифференцировать уравнения, пока не получится одно ДУ высшего порядка.
# 3. Решить его и подставить обратно в исходные уравнения для нахождения остальных функций.
#
# **Важно:** Не все системы можно свести к одному уравнению, но для линейных систем с постоянными коэффициентами это часто возможно.
